# %% [markdown]
# # Pandas Foundation

# %% [markdown]
# ## Basic Pandas

# %% [markdown]
# ### Getting started with pandas

# %%
import pandas as pd

# %% [markdown]
# ### Create dataframe from scratch

# %%
## Create dataframe from scratch
raw_data = {
    "name":["Toy", "Joe", "Mary", "John", "Anna"],
    "age":[33, 25, 20, 22, 31],
    "gender":["M", "M", "F", "M", "F"]
}

df = pd.DataFrame(raw_data)

df
# Out:
#    name  age gender
# 0   Toy   33      M
# 1   Joe   25      M
# 2  Mary   20      F
# 3  John   22      M
# 4  Anna   31      F

# %% [markdown]
# ### Add New Colum

# %%
## Add New Colum
df ["city"] = ["London", "London", "London", "Manchester", "Liverpool"]

df
# Out:
#    name  age gender        city
# 0   Toy   33      M      London
# 1   Joe   25      M      London
# 2  Mary   20      F      London
# 3  John   22      M  Manchester
# 4  Anna   31      F   Liverpool

# %%
df.shape
# Out:
# (5, 4)

# %% [markdown]
# ### Drop column, row, reset index

# %%
## Drop column, row, reset index
df = df.drop("city",axis=1)
## axis 0 rows 1 columns
df
# Out:
#    name  age gender
# 0   Toy   33      M
# 1   Joe   25      M
# 2  Mary   20      F
# 3  John   22      M
# 4  Anna   31      F

# %%
### remove index =2
df = df.drop(2,axis=0)
df
# Out:
#    name  age gender
# 0   Toy   33      M
# 1   Joe   25      M
# 3  John   22      M
# 4  Anna   31      F

# %%
### reset index
df = df.reset_index(drop = True)
df
# Out:
#    name  age gender
# 0   Toy   33      M
# 1   Joe   25      M
# 2  John   22      M
# 3  Anna   31      F

# %% [markdown]
# ### Rename columns

# %%
## Rename columns
list(df.columns)
# Out:
# ['nickname', 'age', 'sex', 'city']

# %%
df.columns = ["nickname", "age", "sex"]
df
# Out:
#   nickname  age sex
# 0      Toy   33   M
# 1      Joe   25   M
# 2     John   22   M
# 3     Anna   31   F

# %% [markdown]
# ### Series vs DataFrame

# %%
## Series vs DataFrame
# แต่ละ Columns/ Rows เป็น series ของ data frame 
type(df["nickname"])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# create a new series
s1 = pd.Series(["Mary", "20", "F"], index =["nickname", "age", "sex"] )
print(s1)
print(type(s1))
# Out:
# nickname    Mary
# age           20
# sex            F
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
# append s1 to df
df = df.append(s1, ignore_index = True)
df
# Out:
#   nickname age sex
# 0      Toy  33   M
# 1      Joe  25   M
# 2     John  22   M
# 3     Anna  31   F
# 4     Mary  20   F

# %%
s2 = pd.Series(["London", "London", "London", "Manchester", "Liverpool"])
df["city"] = s2
df
# Out:
#   nickname age sex        city
# 0      Toy  33   M      London
# 1      Joe  25   M      London
# 2     John  22   M      London
# 3     Anna  31   F  Manchester
# 4     Mary  20   F   Liverpool

# %% [markdown]
# ### Write dataframe to CSV file

# %%
## Write dataframe to CSV file
df.to_csv("mydata.csv")

# %% [markdown]
# ### Import file

# %%
##import csv file
df2 = pd.read_csv("Data/data.csv")
df2
# Out:
#    id   name        city
# 0   1   John      London
# 1   2    Joe   Liverpool
# 2   3   Mary  Manchester
# 3   4   Anna     Swansea
# 4   5  David      London

# %%
##import excel file
df3 = pd.read_excel("Data/data.xlsx")
df3
# Out:
#    id   name        city
# 0   1   John      London
# 1   2    Joe   Liverpool
# 2   3   Mary  Manchester
# 3   4   Anna     Swansea
# 4   5  David      London

# %%
##import JSON file
df4 = pd.read_json("Data/data.json")
df4
# Out:
#                          ebook language  amazonRating  my_favorite
# 0  Getting started with Python   python          4.89         True
# 1            Introduction to R        r          4.88        False
# 2            SQL for Beginners      sql          4.75         True

# %%
df4["my_favorite"].dtype
# Out:
# dtype('bool')

# %% [markdown]
# ## Intermediate-pandas

# %%
import pandas as pd

# %% [markdown]
# ### import penguins data

# %%
## import penguins data 
penguins = pd.read_csv("Data/penguins.csv")

# %%
## preview first 5 row
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
## Preview last 5 row
penguins.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %%
## shape data frame   
### attributes เป็นตัวแปรที่ใช้กำหนดค่าบางอย่างของ data frame ก้อนนี้
penguins.shape
# Out:
# (344, 7)

# %%
## inFormation of dataframe
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Select columns

# %%
## select columns
penguins["species"]
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
penguins.species.head()
# Out:
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# Name: species, dtype: object

# %%
penguins[ ["species", "island", "sex"]].head(3)
# Out:
#   species     island     sex
# 0  Adelie  Torgersen    MALE
# 1  Adelie  Torgersen  FEMALE
# 2  Adelie  Torgersen  FEMALE

# %% [markdown]
# ### Integer location based indexing (iloc)

# %%
## Integer location based indexing (iloc)
mini_penguins = penguins.iloc[0:5,0:3]
mini_penguins
# Out:
#   species     island  bill_length_mm
# 0  Adelie  Torgersen            39.1
# 1  Adelie  Torgersen            39.5
# 2  Adelie  Torgersen            40.3
# 3  Adelie  Torgersen             NaN
# 4  Adelie  Torgersen            36.7

# %% [markdown]
# ### Filter dataframe one condition

# %%
## Filter dataframe one condition
penguins[penguins['island'] == "Torgersen"].head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
penguins[penguins['bill_length_mm'] < 34]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 142  Adelie      Dream            32.1           15.5              188.0
#
#      body_mass_g     sex
# 70        3600.0  FEMALE
# 98        2900.0  FEMALE
# 142       3050.0  FEMALE

# %% [markdown]
# ### Filter dataframe more than one conditions

# %%
## Filter dataframe more than one conditions
### and case
penguins[(penguins["island"]=="Torgersen") & (penguins["bill_length_mm"]< 35)]
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 70  Adelie  Torgersen            33.5           19.0              190.0
# 80  Adelie  Torgersen            34.6           17.2              189.0
#
#     body_mass_g     sex
# 8        3475.0     NaN
# 14       4400.0    MALE
# 18       3325.0  FEMALE
# 70       3600.0  FEMALE
# 80       3200.0  FEMALE

# %%
### or case
filtered_penguins = penguins[(penguins["island"] == "Torgensen") | (penguins["bill_length_mm"] <35)]
filtered_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 18   Adelie  Torgersen            34.4           18.4              184.0
# 54   Adelie     Biscoe            34.5           18.1              187.0
# 70   Adelie  Torgersen            33.5           19.0              190.0
# 80   Adelie  Torgersen            34.6           17.2              189.0
# 92   Adelie      Dream            34.0           17.1              185.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 142  Adelie      Dream            32.1           15.5              188.0
#
#      body_mass_g     sex
# 8         3475.0     NaN
# 14        4400.0    MALE
# 18        3325.0  FEMALE
# 54        2900.0  FEMALE
# 70        3600.0  FEMALE
# 80        3200.0  FEMALE
# 92        3400.0  FEMALE
# 98        2900.0  FEMALE
# ...

# %% [markdown]
# ### Filter with Query

# %%
## Filter with Query
### one condition
penguins.query('island == "Torgersen"').head() ## "island == 'Torgersen'"
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
### more than one conditions  ### and case
penguins.query('island == "Torgersen" & bill_length_mm <35')
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 70  Adelie  Torgersen            33.5           19.0              190.0
# 80  Adelie  Torgersen            34.6           17.2              189.0
#
#     body_mass_g     sex
# 8        3475.0     NaN
# 14       4400.0    MALE
# 18       3325.0  FEMALE
# 70       3600.0  FEMALE
# 80       3200.0  FEMALE

# %%
### more than one conditions  ### or case
penguins.query('island == "Torgersen" | bill_length_mm <35').head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ### Check missing Values

# %%
## Check missing Values
penguins.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
### filter missing values in column sex
penguins[penguins["sex"].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# ...

# %%
### drop na
clean_penguins = penguins.dropna()
clean_penguins.head(10)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
#
#     body_mass_g     sex
# 0        3750.0    MALE
# 1        3800.0  FEMALE
# 2        3250.0  FEMALE
# 4        3450.0  FEMALE
# 5        3650.0    MALE
# ...

# %% [markdown]
# ### Fill missing values (mean imputation)

# %%
## Fill missing values (mean imputation)
top5_penguins = penguins.head(5)

# %%
avg_value = top5_penguins["bill_length_mm"].mean()
print(avg_value)
# Out:
# 38.9

# %%
top5_penguins = top5_penguins["bill_length_mm"].fillna(value = avg_value)
top5_penguins
# Out:
# 0    39.1
# 1    39.5
# 2    40.3
# 3    38.9
# 4    36.7
# Name: bill_length_mm, dtype: float64

# %% [markdown]
# ### Sort dataframe

# %%
## Sort dataframe (bill_length_mm low to high, high to low)
penguins.sort_values("bill_length_mm") ## low to high
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 142     Adelie      Dream            32.1           15.5              188.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 70      Adelie  Torgersen            33.5           19.0              190.0
# 92      Adelie      Dream            34.0           17.1              185.0
# 8       Adelie  Torgersen            34.1           18.1              193.0
# ..         ...        ...             ...            ...                ...
# 321     Gentoo     Biscoe            55.9           17.0              228.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 253     Gentoo     Biscoe            59.6           17.0              230.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 339     Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 142       3050.0  FEMALE
# ...

# %%
penguins.dropna().sort_values("bill_length_mm", ascending = False).head(10) ## high to low
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253     Gentoo  Biscoe            59.6           17.0              230.0
# 169  Chinstrap   Dream            58.0           17.8              181.0
# 321     Gentoo  Biscoe            55.9           17.0              228.0
# 215  Chinstrap   Dream            55.8           19.8              207.0
# 335     Gentoo  Biscoe            55.1           16.0              230.0
# 283     Gentoo  Biscoe            54.3           15.7              231.0
# 183  Chinstrap   Dream            54.2           20.8              201.0
# 191  Chinstrap   Dream            53.5           19.9              205.0
# 327     Gentoo  Biscoe            53.4           15.8              219.0
# 181  Chinstrap   Dream            52.8           20.0              205.0
#
#      body_mass_g     sex
# 253       6050.0    MALE
# 169       3700.0  FEMALE
# 321       5600.0    MALE
# 215       4000.0    MALE
# 335       5850.0    MALE
# ...

# %%
### sort multiple columns
penguins.dropna().sort_values(["island", "bill_length_mm"], ascending = False)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 73   Adelie  Torgersen            45.8           18.9              197.0
# 129  Adelie  Torgersen            44.1           18.0              210.0
# 131  Adelie  Torgersen            43.1           19.2              197.0
# 81   Adelie  Torgersen            42.9           17.6              196.0
# ..      ...        ...             ...            ...                ...
# 66   Adelie     Biscoe            35.5           16.2              195.0
# 25   Adelie     Biscoe            35.3           18.9              187.0
# 52   Adelie     Biscoe            35.0           17.9              190.0
# 100  Adelie     Biscoe            35.0           17.9              192.0
# 54   Adelie     Biscoe            34.5           18.1              187.0
#
#      body_mass_g     sex
# 19        4200.0    MALE
# 73        4150.0    MALE
# ...

# %% [markdown]
# ### Unique and count values

# %%
## Unique and count values
### Unique values
penguins["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
### Count values
penguins["species"].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
### Count more than one columns values
result = penguins[["island","species"]].value_counts().reset_index()
result.columns = ["island", "species", "count"]
result
# Out:
#       island    species  count
# 0     Biscoe     Gentoo    124
# 1      Dream  Chinstrap     68
# 2      Dream     Adelie     56
# 3  Torgersen     Adelie     52
# 4     Biscoe     Adelie     44

# %% [markdown]
# ### Describe dataframe

# %%
## summarise dataframe
penguins.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# ...

# %%
### average , mean
penguins['bill_length_mm'].median()
# Out:
# 44.45

# %% [markdown]
# ### Group by

# %%
## Group by + sum/mean
### penguins[penguins["species"]=="Adelie"]['bill_length_mm'].mean()

penguins.groupby('species')['bill_length_mm'].mean()
# Out:
# species
# Adelie       38.791391
# Chinstrap    48.833824
# Gentoo       47.504878
# Name: bill_length_mm, dtype: float64

# %% [markdown]
# ### Group by aggregation

# %%
## Group by aggregation
penguins.groupby('species')['bill_length_mm'].agg(["min", "mean", "median", "std", "max"])
# Out:
#             min       mean  median       std   max
# species
# Adelie     32.1  38.791391   38.80  2.663405  46.0
# Chinstrap  40.9  48.833824   49.55  3.339256  58.0
# Gentoo     40.9  47.504878   47.30  3.081857  59.6

# %%
### group by more than one columns
result = penguins.groupby(['island',"species"])['bill_length_mm'].agg(["min", "mean", "median", "std", "max"]).reset_index()

result.to_csv('result.csv')

# %% [markdown]
# ### If your code is long

# %%
## If your code is long
result = penguins.groupby(['island',"species"])['bill_length_mm']\
    .agg(["min", "mean", "median", "std", "max"])\
    .reset_index()
    
result
# Out:
#       island    species   min       mean  median       std   max
# 0     Biscoe     Adelie  34.5  38.975000   38.70  2.480916  45.6
# 1     Biscoe     Gentoo  40.9  47.504878   47.30  3.081857  59.6
# 2      Dream     Adelie  32.1  38.501786   38.55  2.465359  44.1
# 3      Dream  Chinstrap  40.9  48.833824   49.55  3.339256  58.0
# 4  Torgersen     Adelie  33.5  38.950980   38.90  3.025318  46.0

# %% [markdown]
# ### Map values

# %%
## Map values MALE : m,  FEMALE : f
penguins['sex_new'] = penguins["sex"].map({"MALE":"m", "FEMALE" : "f"}).head(10).fillna("Other")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex sex_new
# 0       3750.0    MALE       m
# 1       3800.0  FEMALE       f
# 2       3250.0  FEMALE       f
# 3          NaN     NaN   Other
# 4       3450.0  FEMALE       f

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ## Bonus Videos

# %% [markdown]
# ### Hello NumPy

# %%
### pandas style
penguins["bill_length_mm"].mean()
# Out:
# 43.9219298245614

# %%
### Hello NumPy(Numerical Python)
import numpy as np

# %%
np.mean(penguins["bill_length_mm"])
# Out:
# 43.9219298245614

# %%
### other function numpy
np.sum(penguins["bill_depth_mm"])
np.std(penguins["body_mass_g"])
# Out:
# 800.7812292384522

# %% [markdown]
# ### Where

# %%
## Where
score = pd.Series([80, 55, 62, 95, 20])

# %%
grade = np.where(score >= 80, "pass", "failed")
print(grade)
# Out:
# ['pass' 'failed' 'failed' 'pass' 'failed']

# %%
df = penguins.query("species == 'Adelie' ")[["species", "island", "bill_length_mm"]].dropna()

# %%
df.head()
# Out:
#   species     island  bill_length_mm
# 0  Adelie  Torgersen            39.1
# 1  Adelie  Torgersen            39.5
# 2  Adelie  Torgersen            40.3
# 4  Adelie  Torgersen            36.7
# 5  Adelie  Torgersen            39.3

# %%
df['new_column'] = np.where(df["bill_length_mm"] > 40, True, False)

# %%
df.head(10)
# Out:
#    species     island  bill_length_mm  new_column
# 0   Adelie  Torgersen            39.1       False
# 1   Adelie  Torgersen            39.5       False
# 2   Adelie  Torgersen            40.3        True
# 4   Adelie  Torgersen            36.7       False
# 5   Adelie  Torgersen            39.3       False
# 6   Adelie  Torgersen            38.9       False
# 7   Adelie  Torgersen            39.2       False
# 8   Adelie  Torgersen            34.1       False
# 9   Adelie  Torgersen            42.0        True
# 10  Adelie  Torgersen            37.8       False

# %% [markdown]
# ### Merge

# %%
left = {
    'key': [1, 2, 3, 4],
    'name': ['toy', 'joe', 'jane', 'anna'],
    'age': [25, 28, 30, 22]
}

right = {
    'key': [1, 2, 3, 4],
    'city': ['Bangkok', 'London', 'Seoul', 'Tokyo'],
    'zip': [1001, 2504, 2094, 9802]
}

df_left = pd.DataFrame(left)
df_right = pd.DataFrame(right)

# %%
df_left
# Out:
#    key  name  age
# 0    1   toy   25
# 1    2   joe   28
# 2    3  jane   30
# 3    4  anna   22

# %%
df_result = pd.merge(df_left, df_right, on="key")
df_result
# Out:
#    key  name  age     city   zip
# 0    1   toy   25  Bangkok  1001
# 1    2   joe   28   London  2504
# 2    3  jane   30    Seoul  2094
# 3    4  anna   22    Tokyo  9802

# %% [markdown]
# ###Intro to pandas plots

# %%
## Intro to pandas plots
### histogram one column
penguins["body_mass_g"].plot(kind='hist');

# %%
### histogram two column
penguins[['body_mass_g', 'bill_length_mm']].plot(kind="hist", bins= 30);

# %%
penguins[['bill_length_mm']].plot(kind="hist", bins= 30, color ="orange");

# %%
### bar plot for species
penguins["species"].value_counts().plot(kind="bar",color=["salmon","orange","yellow"])

# %%
### scatter plot
penguins[['bill_length_mm','bill_depth_mm']]\
    .plot(x='bill_length_mm',y='bill_depth_mm',kind="scatter",color="green");

# %% [markdown]
# ### DataLore Visualization

# %%
### Visualization
Click Visualization create new chart no code
